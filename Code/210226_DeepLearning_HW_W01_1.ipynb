# %%
import numpy as np


### 딥러닝 1강 Gradient Decent 구현

errors = []
w2_grad = []
w1_grad = []
w0_grad = []

w2 = np.random.rand(10)
w1 = np.random.rand(10)
w0 = np.random.rand(10)

x = np.random.rand(10)

y = w2*(x**2) + w1*x + w0

learning_rate = 0.1
num_cnt = 100


for cnt in range(num_cnt):

        
        # ERROR
        error = ((y_hat - y)**2).mean()

        if error < 0.00001 :
            break

        # Gradient
        grad_w2 = 12*w0 + 20*w1 + 36*w2 - 14
        grad_w1 = 8*w0 + 12*w1 + 20*w2 - 10
        grad_w0 = 8*w0 + 8*w1 + 12*w2 - 8
        
        w2 = w2 - (learning_rate * grad_w2)
        w1 = w1 - (learning_rate * grad_w1)
        w0 = w0 - (learning_rate * grad_w0)
        
        # Predict
        y_hat = w2*(x**2) + w1*x + w0
             
        if cnt % 5 == 0:
                print(cnt, w0, w1, w2, error)
                print()
                

print("Result", "-------" * 15)
print(cnt, w0, w1, w2, error)
# Out:
# 0 [-0.02915536  0.51502936 -0.31577684 -0.4792619  -0.2194664  -0.02123562
#  -0.236833    0.43672209  0.01318735  0.5316756 ] [-0.13227608 -0.0850208  -0.47679346 -1.13453316 -0.47391459 -0.23847286
#  -1.05129526  0.31709155 -0.9389244   0.83607828] [-0.78616989 -0.78311384 -1.87079648 -2.11065536 -1.12876741 -1.40832622
#  -1.40144562  0.02337105 -1.6812286   0.65771744] 1.5845517877093631e+124
#
# 5 [ 440.48315396  361.55452161  907.20262237 1135.41945657  645.49352979
#   668.75817182  850.73115804   23.15527147  891.3027909  -301.9607508 ] [ 671.665565    551.08806667 1383.65692107 1731.23643293  984.20925133
#  1019.93107069 1296.76651859   35.12273802 1358.74049611 -460.48655485] [1166.49175606  956.97624157 2404.30386044 3009.44100801 1710.18096231
#  1771.87566219 2254.34321531   59.63679287 2361.88483735 -802.50425928] 183860.0684373112
#
# 10 [ -576690.045857    -473118.85122461 -1188564.99037309 -1487606.49699273
# ...
